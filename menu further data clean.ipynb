# %%
import pandas as pd

# %%
df = pd.read_csv('menu_cleaned.csv')

# %%
df[df['venue'].isna()]
# Out:
#           id                                               name  \
# 15     12478                                                NaN
# 19     12482                                                NaN
# 48     12515                                                NaN
# 85     12560                                                NaN
# 102    12583                                                NaN
# ...      ...                                                ...
# 16955  35515                                      Hotel LaSalle
# 16956  35516                                          Dennett's
# 16957  35517                                      The Cortlandt
# 16958  35518           Hotel Schynige Platte und Hotel Bellevue
# 16959  35526  Christmas Dinner, Troop F 19: Fort Huachuca, A...
#
#                                                  sponsor   event venue  \
# 15                                                   NaN     NaN   NaN
# ...

# %%
df=df.dropna(subset=['venue'])

# %%
df.to_csv('Cleaned_Menu.csv',index=False)
