# %%
import pandas as pd

# %%
df = pd.read_csv('menupage.csv')

# %%
df[df['full_height'].isna()]
# Out:
#           id  menu_id  page_number    image_id  full_height  full_width  \
# 8        127    12462          2.0  4000001128          NaN         NaN
# 9        128    12462          1.0      474450          NaN         NaN
# 337      514    12582          2.0  4000001128          NaN         NaN
# 338      515    12582          1.0      474450          NaN         NaN
# 4050    5697    14313          2.0  4000017099          NaN         NaN
# ...      ...      ...          ...         ...          ...         ...
# 64315  74810    34943          9.0     5070161          NaN         NaN
# 64316  74811    34943         10.0     5070162          NaN         NaN
# 64317  74812    34943         11.0     5070163          NaN         NaN
# 64967  75462    35037          1.0     5106619          NaN         NaN
# 64968  75463    35037          2.0     5106620          NaN         NaN
#
#                                        uuid
# 8      510d47db-1ef8-a3d9-e040-e00a18064a99
# ...

# %%
df['full_height'].fillna(0,inplace=True)

# %%
df['full_width'].fillna(0,inplace=True)

# %%
df.to_csv('Cleaned_Menupage.csv',index=False)
